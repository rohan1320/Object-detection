# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Fri Jan 15 17:03:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'app-release (1).apk'	'Home assignment'
# 'app-release (2).apk'	 Krishna
# 'app-release (3).apk'	'Lab assignment'
#  app-release.apk	 Laptop
# 'ArtistFinder (1).zip'	'Maze Solver Bot.gslides'
#  ArtistFinder.zip	'My Drive'
# 'Colab Notebooks'	'Necessary documents'
# 'Copy of SD.gslides'	 Other
#  data			 SD.gslides
# 'data (1)'		 Submissions
#  EBC			 Tensorflow
#  EC			 Timetable
# 'Education '		 Trip
#  ET_A_Time_table.pdf	'Untitled presentation.gslides'
# 'Google Photos'		 yolo_custom_model_Training
#  GYM			 yolov3
# 'HA CV'

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14665, done.
# remote: Total 14665 (delta 0), reused 0 (delta 0), pack-reused 14665
# Receiving objects: 100% (14665/14665), 13.25 MiB | 24.06 MiB/s, done.
# Resolving deltas: 100% (9977/9977), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
#!ls /content/gdrive/MyDrive/yolo_custom_model_Training

# %%
#!unzip '/content/gdrive/MyDrive/yolo_custom_model_Training/Custom_data.zip' -d '/content/gdrive/MyDrive/yolo_custom_model_Training/'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet' '/content/gdrive/MyDrive/yolo_custom_model_Training/darknet'

# %%
# Start the training
# !./darknet detector train /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/backup/yolo-obj_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.538385), count: 18, class_loss = 5.737160, iou_loss = 32.137974, total_loss = 37.875134
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.604139), count: 24, class_loss = 7.333770, iou_loss = 6.993842, total_loss = 14.327612
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.666725), count: 30, class_loss = 9.538617, iou_loss = 2.094354, total_loss = 11.632971
#  total_bbox = 300003, rewritten_bbox = 0.476662 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.523482), count: 11, class_loss = 4.267648, iou_loss = 15.356494, total_loss = 19.624142
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.588236), count: 27, class_loss = 10.500517, iou_loss = 7.286068, total_loss = 17.786585
# ...

# %%
#Start testing
# !./darknet detect /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/backup/yolo-obj_last.weights
