# %%
from google.colab import drive
drive.mount("/content/gdrive")
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '10303320171124511003 (1).pdf'
# '10303320171124511003 (2).pdf'
# '10303320171124511003 (3).pdf'
#  10303320171124511003.pdf
# 'Alp Mali.jpg'
#  bank_receipts
# ' book bank 2018.pdf'
#  CHARACTERISTICS.gdoc
#  Classroom
# 'CN Assignment (1).doc'
# 'CN Assignment.doc'
# 'Colab Notebooks'
# 'commercial geography assignment 2.pdf'
#  counclling
#  cp2_prime.cpp
# 'Dog Vision'
#  Dog-Vision
#  fee-receipt.pdf
# 'Getting started.pdf'
#  Google-Colab-CHARACTERISTICS.docx
#  growth-mindset.mp4
# 'https:  mhtcet2019.mahaonline.gov.in MHTCETHallTicket HallTicket'
# 'IMG20200226144036 (1).jpg'
#  IMG20200226144036.jpg
#  IMG20200728101514.jpg
#  introduction.mp4
# 'Invitation Letter.pdf'
# 'JDBC_ DURGA.pdf'
#  Jovian
#  Learning_Python_5th_Edition.pdf
#  linear-regression-from-scratch
#  logistic-regression-from-scratch
# 'Love Babbar'
#  M5-Competitors-Guide-Final-10-March-2020.gdoc
#  machine-learning-ex1
# 'Mali Cast.jpg'
#  MOJO9808G00D18935004.pdf
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15185, done.
# remote: Total 15185 (delta 0), reused 0 (delta 0), pack-reused 15185
# Receiving objects: 100% (15185/15185), 13.59 MiB | 22.55 MiB/s, done.
# Resolving deltas: 100% (10310/10310), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
from pylab import *

# %%
from google.colab.patches import cv2_imshow

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/Test_images/0b47a98a3700dd7e.jpg -thresh 0.05
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/Test_images/4d1ca372d780c875.jpg -thresh 0.05
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/Test_images/test1.jpg -thresh 0.1
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/test2.jpg -thresh 0.1
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/test3.jpg -thresh 0.1
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/Test_images/2c90d4c1f8b5c5b2.jpg -thresh 0.1
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#Start testing
# !./darknet detector test /content/gdrive/MyDrive/yolo_custom_model_Training/data.data /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj.cfg /content/gdrive/MyDrive/yolo_custom_model_Training/yolo-obj_last.weights /content/gdrive/MyDrive/yolo_custom_model_Training/Test_images/motorcycle1.jpeg -thresh 0.1
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...
